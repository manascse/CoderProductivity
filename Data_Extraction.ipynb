# %%
import pandas as pd
import random as rd
import numpy as np
import csv
from fitter import Fitter, get_common_distributions, get_distributions

# %%
# synthetic classification dataset
from numpy import where
from sklearn.datasets import make_classification
from matplotlib import pyplot
# affinity propagation clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot
import warnings
warnings.filterwarnings("ignore")

# %%
for i in range(25):  # Iterates from 0 to 4
    df=pd.read_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\Data_1828\SampleData_Mutlistage_Stratified_2017_2019_1828_'+str(i+1)+'.csv')
    cols = ['ELS_DAYS']
    features = df[cols]
    features.head()
    features.to_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\Data_1828\SampleData_Mutlistage_Stratified_2017_2019_1828_ELOS_'+str(i+1)+'.csv', header=False,index=False)

# %%
for i in range(25):  # Iterates from 0 to 4
    ELOS=pd.read_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\Data_1828\SampleData_Mutlistage_Stratified_2017_2019_1828_ELOS_'+str(i+1)+'.csv')
    f = Fitter(ELOS,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "norm",
                         "halfnorm"])
    f.fit()
    bestDistribution=f.get_best(method = 'sumsquare_error')
    strBestDistribution = str(bestDistribution);
    parts = strBestDistribution.split(':');
    print(f"Best Method: {parts[0]}")
# Out:
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'beta'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
# Best Method: {'lognorm'
