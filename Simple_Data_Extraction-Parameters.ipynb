# %%
import pandas as pd
import random as rd
import numpy as np

# %%
# synthetic classification dataset
from numpy import where
from sklearn.datasets import make_classification
from matplotlib import pyplot
# affinity propagation clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot
import warnings
warnings.filterwarnings("ignore")

# %%
#df = pd.read_csv('InputData_Except_9_Series_1.csv')
#df = pd.read_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Input_Data_Updated_Except_CMG_900_Series_2017_2019_1.csv')
df = pd.read_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\Data_15984\SampleData_Simple_2017_2019_15984_1.csv')
df.head()
# Out:
#    AGRP_F_D  GENDER  X_FR_I_T  ADM_CAT  ENT_CODE  X_TO_I_T  DIS_DISP  \
# 0         0       1         0        2         4         0         5
# 1         7       1         0        3         3         0         5
# 2        17       1         0        3         2         0        40
# 3        11       0         0        3         3         0         5
# 4        14       1         4        3         3         0         7
#
#    TLOS_CAT  ACT_LCAT  ALC_LCAT  IP_RIW  ELS_DAYS
# 0         1         1         0  0.1370       1.3
# 1         3         3         0  0.6508       5.1
# 2         3         3         0  1.7377       8.3
# 3         1         1         0  0.7429       4.2
# 4         3         3         0  5.0951      24.6

# %%
pyplot.scatter(df['IP_RIW'], df['ELS_DAYS'])
pyplot.show()

# %%
fileLocation = 'D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\660\SampleData_Simple_2017_2019_660_'

# %%
def systematic_sample(df, size):
    length = len(df)
    interval = length // size
    rd.seed(None)
    first = rd.randint(0, interval)
    indexes = np.arange(first, length, step = interval)
    return df.iloc[indexes]

# %%
def simple_sample(df,size):
    return df.sample(
        n=size,
        replace=False,
        random_state=None
    )

# %%
for i in range(2):  # Iterates from 0 to 4
    df_simple = simple_sample(df,size=1828)
    df_simple.to_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\Data_15984\SampleData_Simple_2017_2019_15984_1828_'+str(i+1)+'.csv', index=False)

# %%
#df_simple.to_csv(fileLocation+str(i+1)+'.csv', index=False)
df_simple.to_csv('D:\Manas PhD Den\CoderProducvity\Research_Papers\Data\Data_2017_19\Data_15984\SampleData_Simple_2017_2019_20480_2_1.csv', index=False)
